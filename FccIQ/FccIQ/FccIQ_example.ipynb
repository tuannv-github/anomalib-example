# %%
# 1. Import required modules
from anomalib.data import MVTecAD
from anomalib.engine import Engine
from anomalib.models import EfficientAd
# Out:
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/openvino/runtime/__init__.py:10: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   warnings.warn(

# %%
import importlib
import FccIQ
importlib.reload(FccIQ)
from FccIQ import FccIQ

datamodule = FccIQ(
    root="../datasets/FccIQ",
    train_batch_size=1,  # Number of images per training batch
    )
datamodule.setup()

print("--- Train Data ---")
print(datamodule.train_data.samples)
print("--- Test Data ---")
print(datamodule.test_data.samples)

print("--- Train Dataloader ---")
i, data = next(enumerate(datamodule.train_dataloader()))
print(data.image.shape)

print("--- Test Dataloader ---")
i, data = next(enumerate(datamodule.test_dataloader()))
print(data.image.shape)
# Out:
# --- Train Data ---
#                                                    path  split label  \
# 0     /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 1     /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 2     /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 3     /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 4     /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# ...                                                 ...    ...   ...
# 5220  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 5221  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 5222  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 5223  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
# 5224  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train  good
#
#                                              image_path  label_index mask_path
# 0     /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 1     /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 2     /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 3     /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 4     /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# ...                                                 ...          ...       ...
# 5220  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 5221  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 5222  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 5223  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 5224  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
#
# [5225 rows x 6 columns]
# --- Test Data ---
#                                                    path  split        label  \
# 0     /home/vantuan_ngo/anomalib-example/datasets/Fc...   test  single_tone
# 1     /home/vantuan_ngo/anomalib-example/datasets/Fc...   test  single_tone
# 2     /home/vantuan_ngo/anomalib-example/datasets/Fc...   test  single_tone
# 3     /home/vantuan_ngo/anomalib-example/datasets/Fc...   test  single_tone
# 4     /home/vantuan_ngo/anomalib-example/datasets/Fc...   test  single_tone
# ...                                                 ...    ...          ...
# 1889  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train         good
# 1890  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train         good
# 1891  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train         good
# 1892  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train         good
# 1893  /home/vantuan_ngo/anomalib-example/datasets/Fc...  train         good
#
#                                              image_path  label_index  \
# 0     /home/vantuan_ngo/anomalib-example/datasets/Fc...            1
# 1     /home/vantuan_ngo/anomalib-example/datasets/Fc...            1
# 2     /home/vantuan_ngo/anomalib-example/datasets/Fc...            1
# 3     /home/vantuan_ngo/anomalib-example/datasets/Fc...            1
# 4     /home/vantuan_ngo/anomalib-example/datasets/Fc...            1
# ...                                                 ...          ...
# 1889  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 1890  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 1891  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 1892  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
# 1893  /home/vantuan_ngo/anomalib-example/datasets/Fc...            0
#
#                                               mask_path
# 0     /home/vantuan_ngo/anomalib-example/datasets/Fc...
# 1     /home/vantuan_ngo/anomalib-example/datasets/Fc...
# 2     /home/vantuan_ngo/anomalib-example/datasets/Fc...
# 3     /home/vantuan_ngo/anomalib-example/datasets/Fc...
# 4     /home/vantuan_ngo/anomalib-example/datasets/Fc...
# ...                                                 ...
# 1889
# 1890
# 1891
# 1892
# 1893
#
# [1894 rows x 6 columns]
# --- Train Dataloader ---
# torch.Size([1, 3, 300, 14])
# --- Test Dataloader ---
# torch.Size([32, 3, 300, 14])

# %%
# 3. Initialize the model
# EfficientAd is a good default choice for beginners
model = EfficientAd()

# %%
# 4. Create the training engine
engine = Engine(max_epochs=20)  # Train for 10 epochs

# %%
# 5. Train the model
engine.fit(datamodule=datamodule, model=model)
# Out:
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name           | Type             | Params | Mode
# ------------------------------------------------------------
# 0 | pre_processor  | PreProcessor     | 0      | train
# 1 | post_processor | PostProcessor    | 0      | train
# 2 | evaluator      | Evaluator        | 0      | train
# 3 | model          | EfficientAdModel | 8.1 M  | train
# ------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 48        Modules in train mode
# 7         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/lightning_model.py:170: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Calculate teacher channel mean & std: 100%|██████████| 5225/5225 [00:10<00:00, 494.21it/s]
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/lightning/pytorch/core/module.py:512: You called `self.log('train_st', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/lightning/pytorch/core/module.py:512: You called `self.log('train_ae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/lightning/pytorch/core/module.py:512: You called `self.log('train_stae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/lightning/pytorch/core/module.py:512: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.78it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.92it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.90it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.89it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.90it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.83it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.86it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.84it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.84it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.87it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.78it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.85it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.85it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.86it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.88it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.87it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.83it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.84it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.87it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 60/60 [00:07<00:00,  7.85it/s]
# `Trainer.fit` stopped: `max_epochs=20` reached.

# %%
print(engine.trainer.checkpoint_callback.best_model_path)
# Out:
# /home/vantuan_ngo/anomalib-example/FccIQ/results/EfficientAd/FccIQ/synthetic/v17/weights/lightning/model.ckpt

# %%
# load best model from checkpoint before evaluating
test_results = engine.test(
    model=model,
    datamodule=datamodule,
    ckpt_path=engine.trainer.checkpoint_callback.best_model_path,
)
# Out:
# The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# Restoring states from the checkpoint path at /home/vantuan_ngo/anomalib-example/FccIQ/results/EfficientAd/FccIQ/synthetic/v17/weights/lightning/model.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Loaded model weights from the checkpoint at /home/vantuan_ngo/anomalib-example/FccIQ/results/EfficientAd/FccIQ/synthetic/v17/weights/lightning/model.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.6959962248802185     │
# │       image_F1Score       │    0.5959183573722839     │
# │        pixel_AUROC        │    0.6700396537780762     │
# │       pixel_F1Score       │   0.022449158132076263    │
# └───────────────────────────┴───────────────────────────┘

# %%
print(test_results)
# Out:
# [{'image_AUROC': 0.6959962248802185, 'image_F1Score': 0.5959183573722839, 'pixel_AUROC': 0.6700396537780762, 'pixel_F1Score': 0.022449158132076263}]

# %%
from anomalib.deploy import ExportType
engine.export(
    model=model,
    export_type=ExportType.OPENVINO,
)
# Out:
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/torch/onnx/utils.py:1963: UserWarning: Provided key output for dynamic axes is not a valid input/output name
#   warnings.warn(
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/torch_model.py:66: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   mean = torch.tensor([0.485, 0.456, 0.406])[None, :, None, None].to(x.device)
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/torch_model.py:67: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   std = torch.tensor([0.229, 0.224, 0.225])[None, :, None, None].to(x.device)
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/torch_model.py:526: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   return any(value.sum() != 0 for _, value in p_dic.items())
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/torch_model.py:359: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   math.ceil(image_size[0] / 4) if self.padding else math.ceil(image_size[0] / 4) - 8,
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/models/image/efficient_ad/torch_model.py:360: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   math.ceil(image_size[1] / 4) if self.padding else math.ceil(image_size[1] / 4) - 8,
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:209: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pred_score = predictions.pred_score or torch.amax(predictions.anomaly_map, dim=(-2, -1))
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:325: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not self._image_threshold.isnan():
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:311: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if preds is None or norm_min.isnan() or norm_max.isnan():
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:313: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if threshold.isnan():
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:338: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not self._pixel_threshold.isnan():
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:349: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   return torch.tensor(1.0) - self.image_sensitivity
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:289: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if preds is None or threshold.isnan():
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/anomalib/post_processing/post_processor.py:358: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   return torch.tensor(1.0) - self.pixel_sensitivity
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/torch/onnx/_internal/jit_utils.py:308: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/torch/onnx/utils.py:663: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /home/vantuan_ngo/.local/lib/python3.10/site-packages/torch/onnx/utils.py:1186: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# PosixPath('/home/vantuan_ngo/anomalib-example/FccIQ/results/EfficientAd/FccIQ/synthetic/latest/weights/openvino/model.xml')

# %%
from anomalib.data.utils import read_image
from matplotlib import pyplot as plt
# image_path = "../datasets/FccIQ/synthetic/train/good/noise_interference_slot_1.png"
image_path = "../datasets/FccIQ/synthetic/test/single_tone/100.png"
image = read_image(path=image_path)
plt.imshow(image)

# %%
import os
from pathlib import Path
output_path = Path(engine.trainer.default_root_dir)
print(output_path)
# Out:
# /home/vantuan_ngo/anomalib-example/FccIQ/results/EfficientAd/FccIQ/synthetic/latest

# %%
openvino_model_path = output_path / "weights" / "openvino" / "model.bin"
print(openvino_model_path.exists())
# Out:
# True

# %%
from anomalib.deploy import OpenVINOInferencer
inferencer = OpenVINOInferencer(
    path=openvino_model_path,  # Path to the OpenVINO IR model.
    device="CPU",  # We would like to run it on an Intel CPU.
)

# %%
from anomalib.utils.visualization import ImageResult
predictions = inferencer.predict(image=image_path)
predictions = ImageResult.from_dataset_item(predictions.items[0])  # convert to imageresult for visualization

# %%
# Visualize the original image
plt.imshow(predictions.image)
print(predictions.image.shape)
# Out:
# (256, 256, 3)

# %%
# Visualize the raw anomaly maps predicted by the model.
plt.imshow(predictions.anomaly_map)
plt.colorbar()  # Add colorbar to show the scale
plt.title("Anomaly Map")
plt.show()

# %%
# Visualize the heatmaps, on which raw anomaly map is overlayed on the original image.
plt.imshow(predictions.heat_map)
plt.colorbar()  # Add colorbar to show the scale

# %%
# Visualize the segmentation mask.
plt.imshow(predictions.pred_mask)
plt.colorbar()  # Add colorbar to show the scale
plt.title("Segmentation Mask")
plt.show()
